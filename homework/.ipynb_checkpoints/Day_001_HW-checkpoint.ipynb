# %% [markdown]
# ## 作業1：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：<br>
#
# crimes in Boston<br>
# https://www.kaggle.com/ankkur13/boston-crime-data<br>
#
# 1.你選的這組資料為何重要<br>
# 日常生活中，犯罪是一種會破壞加害者與被害者家庭的社會事件，若能夠透過分析犯罪事件，有效地抑制犯罪的發生，能夠讓社會有更美好的未來。<br>
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)<br>
# 資料提供者 : Boston Police Department 從2015-2018所收集的資料<br>
# 3.蒐集而來的資料型態為何<br>
# .csv檔<br>
# 結構化的資料：數字or字串<br>
# 4.這組資料想解決的問題如何評估<br>
# 解決問題：若知道某地區某時間容易發生搶案，便可以在可能犯罪的時間地點多派警方駐守。<br>
# 評估：準確率

# %% [markdown]
# ## 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：<br>
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)<br>
# 提升業績：在一定時間內獲得的載客量or載客距離上升，載客量or載客距離增加會使的業績上升。<br>
# 假設能分析出在某時間某地點能載到越多客人抑或是客人需要前往遠處，即可在那時間多派車使需要叫車的客人更容易坐到我們車隊的車。<br>
# 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)<br>
# 載客的乘客數量、時間、地點、距離、天氣、顧客等待時間<br>
# 資料蒐集：司機全程使用開啟GPS定位之手機，在載客的全程進行紀錄即可獲得資料<br>
# 3.蒐集而來的資料型態為何<br>
# 時間：年/月/日/24小時制(數字的時間表示法)<br>
# 地點：以XX縣市YY鄉鎮市區ZZ路等(string型式)<br>
# 距離：float<br>
# 天氣：晴天、雨天、...(string型式)<br>
# 顧客等待時間：float<br>
# 金額：int<br>
# 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)<br>
# 利用金額當應變數，其餘當自變數，找出相關的變數。<br>

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y,yp):
    return sum((y-yp)**2)/len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 261.294
# The Mean absolute error is 12.418
